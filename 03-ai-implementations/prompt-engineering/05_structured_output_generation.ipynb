# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

_ = load_dotenv()

api_key = os.getenv("OPENAI_API_KEY")

client = OpenAI(api_key=api_key)

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {
            "role": "user",
            "content": "Tell me about Python."
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# Python is a high-level, interpreted programming language known for its simplicity, readability, and versatility. It was created by Guido van Rossum and first released in 1991. Python's design philosophy emphasizes code readability and straightforward syntax, which makes it an excellent choice for both beginners and experienced programmers.
#
# Key features of Python include:
#
# 1. **Easy to Learn and Use:** Python's syntax is clear and intuitive, resembling plain English, which helps new programmers pick it up quickly.
#
# 2. **Interpreted Language:** Python code is executed line-by-line, which makes debugging easier and development faster since you don't need to compile code before running it.
#
# 3. **Dynamically Typed:** Variable types are determined at runtime, allowing for flexible and concise code.
#
# 4. **Extensive Standard Library:** Python comes with a large collection of modules and packages for tasks like file I/O, system calls, web development, and data manipulation.
#
# 5. **Cross-Platform:** Python runs on many operating systems including Windows, Linux, and macOS.
#
# 6. **Supports Multiple Paradigms:** Python supports procedural, object-oriented, and functional programming styles.
#
# 7. **Large Community and Ecosystem:** Python has a vast and active community contributing to a huge range of third-party libraries and frameworks, making it popular in areas like web development (Django, Flask), data science (pandas, NumPy), machine learning (TensorFlow, scikit-learn), automation, and more.
#
# Because of these qualities, Python is widely used in various fields such as web development, scientific computing, artificial intelligence, education, automation, and more.

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {
            "role": "system",
            "content": "Always respond in JSON format."
        },
        {
            "role": "user",
            "content": "Tell me about Python."
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# ```json
# {
#   "name": "Python",
#   "type": "Programming Language",
#   "creator": "Guido van Rossum",
#   "first_released": "1991",
#   "paradigms": [
#     "Object-oriented",
#     "Procedural",
#     "Functional"
#   ],
#   "features": [
#     "Easy to learn and use",
#     "Interpreted language",
#     "Dynamic typing",
#     "Automatic memory management",
#     "Extensive standard library",
#     "Supports modules and packages"
#   ],
#   "typical_uses": [
#     "Web development",
#     "Data analysis",
#     "Artificial Intelligence and Machine Learning",
#     "Scientific computing",
#     "Automation and scripting",
#     "Software development"
#   ],
#   "website": "https://www.python.org"
# }
# ```

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {
            "role": "system",
            "content": """
Return JSON only.

Schema:
{
    "name": string,
    "category": string,
    "description": string
}
"""
        },
        {
            "role": "user",
            "content": "Python"
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# {
#     "name": "Python",
#     "category": "Programming Language",
#     "description": "Python is a high-level, interpreted programming language known for its readability, simplicity, and versatility. It supports multiple programming paradigms, including procedural, object-oriented, and functional programming, and is widely used in web development, data analysis, artificial intelligence, scientific computing, and automation."
# }

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {
            "role": "system",
            "content": """
Extract information and return JSON only.

Schema:
{
    "name": string,
    "country": string,
    "occupation": string
}
"""
        },
        {
            "role": "user",
            "content": "Alex is a Python developer from Malaysia."
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# {
#     "name": "Alex",
#     "country": "Malaysia",
#     "occupation": "Python developer"
# }

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {
            "role": "system",
            "content": """
Classify sentiment.

Return JSON only.

Schema:
{
    "sentiment": string
}
"""
        },
        {
            "role": "user",
            "content": "I love Python."
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# ```json
# {
#   "sentiment": "positive"
# }
# ```

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {
            "role": "system",
            "content": """
Classify sentiment.

Return JSON only.

Schema:
{
    "sentiment": string
}
"""
        },
        {
            "role": "user",
            "content": "This movie is terrible."
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# {
#   "sentiment": "negative"
# }

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {
            "role": "system",
            "content": """
Return JSON only.

Schema:
{
    "name": string,
    "category": string,
    "description": string
}
"""
        },
        {
            "role": "user",
            "content": "Java"
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# {
#   "name": "Java",
#   "category": "Programming Language",
#   "description": "Java is a high-level, class-based, object-oriented programming language designed to have as few implementation dependencies as possible. It is widely used for building enterprise-scale applications, web applications, and Android apps."
# }

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {
            "role": "system",
            "content": """
Return JSON only.

Schema:
{
    "name": string,
    "category": string,
    "description": string
}
"""
        },
        {
            "role": "user",
            "content": "JavaScript"
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# {
#   "name": "JavaScript",
#   "category": "Programming Language",
#   "description": "JavaScript is a versatile, high-level programming language commonly used to create interactive effects within web browsers. It enables dynamic content, control over multimedia, animation, and asynchronous communication, making web pages more engaging and responsive."
# }

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {
            "role": "system",
            "content": """
Return JSON only.

Schema:
{
    "name": string,
    "category": string,
    "description": string
}
"""
        },
        {
            "role": "user",
            "content": "C++"
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# {
#   "name": "C++",
#   "category": "Programming Language",
#   "description": "C++ is a high-level, general-purpose programming language created as an extension of the C language. It supports procedural, object-oriented, and generic programming paradigms and is widely used for system/software development, game development, and real-time simulations."
# }
