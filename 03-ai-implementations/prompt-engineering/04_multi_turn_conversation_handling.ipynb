# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

_ = load_dotenv()

api_key = os.getenv("OPENAI_API_KEY")

client = OpenAI(api_key=api_key)

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {
            "role": "user",
            "content": "My name is Oliver."
        },
        {
            "role": "assistant",
            "content": "Nice to meet you, Oliver!"
        },
        {
            "role" : "user",
            "content" : "What's my name?"
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# Your name is Oliver.

# %%
messages = [
    {
        "role": "user",
        "content": "My name is Oliver."
    }
]

response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

assistant_reply = response.choices[0].message.content or ""

messages.append(
    {
        "role": "assistant",
        "content": assistant_reply
    }
)

messages.append(
    {
        "role": "user",
        "content": "What is my name?"
    }
)

response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# Your name is Oliver. How can I help you today, Oliver?

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {
            "role": "user",
            "content": "My favorite language is Python."
        },
        {
            "role": "assistant",
            "content": "Python is a great language."
        },
        {
            "role": "user",
            "content": "What is my favorite language?"
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# Your favorite language is Python.

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {
            "role": "assistant",
            "content": "Python is a great language."
        },
        {
            "role": "user",
            "content": "What is my favorite language?"
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# I don't have information about your favorite language. Could you tell me what it is?

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {
            "role": "user",
            "content": "What is my favorite language?"
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# I don’t know your favorite language yet. Could you tell me more about it?

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {
            "role": "user",
            "content": "My favorite language is Python."
        },
        {
            "role": "assistant",
            "content": "Python is a great language."
        },
        {
            "role": "user",
            "content": "What is my favorite language?"
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# Your favorite language is Python.
