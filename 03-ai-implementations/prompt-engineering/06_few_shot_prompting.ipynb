# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

_ = load_dotenv()

api_key = os.getenv("OPENAI_API_KEY")

client = OpenAI(api_key=api_key)

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {
            "role": "user",
            "content": "Translate 'Hello' to Chinese."
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# "Hello" in Chinese is "你好" (nǐ hǎo).

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {
            "role": "user",
            "content": """
Translate English to Chinese.

Dog -> 狗
Cat -> 猫
Apple -> 苹果

Hello ->
"""
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# Hello -> 你好

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {
            "role": "user",
            "content": """
Classify the sentiment.

Text:
I love Python.
"""
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# The sentiment of the text "I love Python." is positive.

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {
            "role": "user",
            "content": """
Classify sentiment.

I love this movie. -> Positive
This food is terrible. -> Negative
The service was excellent. -> Positive

I love Python. ->
"""
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# I love Python. -> Positive

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {
            "role": "user",
            "content": """
John is a Java developer from Canada.

Name: John
Country: Canada
Occupation: Java Developer

Alex is a Python developer from Malaysia.
"""
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# Name: Alex
# Country: Malaysia
# Occupation: Python Developer

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {
            "role": "user",
            "content": """
Return JSON.

Python

{
  "name": "Python",
  "category": "Programming Language"
}

Java

{
  "name": "Java",
  "category": "Programming Language"
}

JavaScript
"""
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# ```json
# {
#   "name": "JavaScript",
#   "category": "Programming Language"
# }
# ```
